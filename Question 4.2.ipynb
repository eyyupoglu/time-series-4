# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import numpy as np
from tools import *

# %%
import pandas as pd
df = pd.read_csv('data_building.csv')
# df.index = df.timedatae
df.tail()
# Out:
#              timedate      yTi       Ta   Ph      Gv
# 535  14/10/1983 08:30  29.7934  13.3400  1.5  0.4471
# 536  14/10/1983 08:40  29.9078  13.4264  1.5  0.4710
# 537  14/10/1983 08:50  30.0150  13.5994  1.5  0.4508
# 538  14/10/1983 09:00  30.1075  13.6894  1.5  0.3748
# 539  14/10/1983 09:10  30.0125  13.9400  0.0  0.3199

# %%
plt.scatter(range(len(df.index)), df['Ph'])
plt.title('Ph', size=20)
plt.xlabel('Time(measured every 5 minutes)', size=15)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df.index, df['yTi'], label='yTi')
plt.legend(loc='upper left', prop={'size': 15})
plt.show()

######
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df.index, df['Ta'], label='Ta')
plt.legend(loc='upper left', prop={'size': 15})
plt.show()

######
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df.index, df['Ph'], label='Ph')
plt.legend(loc='upper left', prop={'size': 15})
plt.show()

######
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df.index, df['Gv'], label='Gv')
plt.legend(loc='upper left', prop={'size': 15})
plt.show()
